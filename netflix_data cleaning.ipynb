# %%
import pandas as pd
from sqlalchemy import create_engine

# Fill in your credentials
username = 'postgres'        # or your chosen username
password = 'root'   # the one you set during install
host = 'localhost'
port = '5432'
database = 'postgres'        # your database name

# Create connection
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')

# %%
df = pd.read_sql("SELECT * FROM public.netflix_data", engine)
df# Show first few rows
# Out:
#    Show_ID                    Title     Type        Genre         Country  \
# 0    s0001             Edge believe    Movie     Thriller  United Kingdom
# 1    s0002   Central ground mission    Movie  Documentary          France
# 2    s0003               During box  TV Show  Documentary          Canada
# 3    s0004        Threat lot course    Movie  Documentary   United States
# 4    s0005          Foreign part or    Movie      Romance           India
# ..     ...                      ...      ...          ...             ...
# 95   s0096              Attack that  TV Show     Thriller          France
# 96   s0097                 Movement    Movie       Comedy         Germany
# 97   s0098      Among never general  TV Show        Drama           Japan
# 98   s0099  Thought heart situation  TV Show     Thriller   United States
# 99   s0100          Adult player we  TV Show     Thriller           India
#
#     Release_Year Rating   Duration  Date_Added   Views  User_Rating
# 0           2008  TV-14    114 min  2024-09-23  924812          6.5
# 1           2012      G     97 min  2020-05-16  691446          4.4
# 2           2002  PG-13  1 Seasons  2024-05-31   32056          6.3
# 3           2002      G    106 min  2021-08-30  671759          1.5
# 4           2016     PG     95 min  2024-11-27  302004          7.0
# ..           ...    ...        ...         ...     ...          ...
# 95          2021      R  7 Seasons  2025-02-02  863085          7.8
# 96          2008  PG-13     93 min  2024-09-07  131552          9.7
# 97          2013  TV-MA  7 Seasons  2023-05-14  206694          5.7
# 98          2006  PG-13  3 Seasons  2020-12-31  585898          2.2
# 99          2000      G  5 Seasons  2023-05-18  648448          8.2
#
# [100 rows x 11 columns]
